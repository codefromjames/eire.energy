# %% [markdown]
# <a href="https://colab.research.google.com/github/codefromjames/eire.energy/blob/main/geocoding.ppr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 13.6 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 24.0 MB/s
# ...

# %%
import pandas as pd
import numpy as np
from google.colab import files
import io

# %%
uploaded = files.upload()
ppr = pd.read_csv(io.BytesIO(uploaded['ppr.not.csv']), encoding= 'unicode_escape')
# Out:
#      <input type="file" id="files-55a329be-8f5f-48ad-b8f0-0587c372f66e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55a329be-8f5f-48ad-b8f0-0587c372f66e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ppr.not.csv to ppr.not.csv

# %%
ppr
# Out:
#       Date of Sale (dd/mm/yyyy)  ... small.area.3
# 0                    14/01/2010  ...   A017022004
# 1                    23/04/2010  ...          NaN
# 2                    14/05/2010  ...          NaN
# 3                    16/07/2010  ...          NaN
# 4                    30/07/2010  ...          NaN
# ...                         ...  ...          ...
# 65530                31/08/2012  ...          NaN
# 65531                10/09/2012  ...          NaN
# 65532                13/09/2012  ...          NaN
# 65533                18/09/2012  ...          NaN
# 65534                20/09/2012  ...          NaN
#
# [65535 rows x 15 columns]
# ...

# %%
ppr

# %%
from geopandas.tools import geocode
from google.colab import files

import time

for index, row in ppr.iterrows():
  try: 
      time.sleep(1)    
      print(row['AddressCO'])
      info = geocode(str(row['AddressCO']), provider = 'nominatim', user_agent = 'my_request' )
      ppr.loc[int(index), 'found'] = info['address'].loc[0]
      ppr.loc[int(index), 'Lon'] = info['geometry'].loc[0].x
      ppr.loc[int(index), 'Lat'] = info['geometry'].loc[0].y
      print(row['index'])
  except Exception as e:
      ppr.loc[int(index), 'found'] =  "No Result"


ppr.to_csv('ppr.geo.csv') 
files.download('ppr.geo.csv')
